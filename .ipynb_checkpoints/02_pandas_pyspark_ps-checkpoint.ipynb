# %%
import pandas as pd

# %%
import pyspark.pandas as ps
# Out:
# WARNING:root:'PYARROW_IGNORE_TIMEZONE' environment variable was not set. It is required to set this environment variable to '1' in both driver and executor sides if you use pyarrow>=2.0.0. pandas-on-Spark will set it for you but it does not work if there is a Spark context already launched.

# %%
ls
# Out:
# 01_intro.ipynb*  02_pandas_pyspark_ps.ipynb*  data/  test1.csv*

# %%
psdf = ps.read_csv('test1.csv')

# %%
psdf.head()
# Out:
#         Name  age  Experience  Salary
# 0      Krish   31          10   30000
# 1  Sudhanshu   30           8   25000
# 2      Sunny   29           4   20000
# 3       Paul   24           3   20000
# 4     Harsha   21           1   15000

# %%
psdf['newcol'] = psdf['Salary']/psdf['age']

# %%
psdf['newcol'].describe()
# Out:
# count      6.000000
# mean     803.493031
# std      100.111686
# min      689.655172
# 25%      714.285714
# 50%      782.608696
# 75%      833.333333
# max      967.741935
# Name: newcol, dtype: float64

# %% [markdown]
# # Compare performance

# %%
# %%time
print('test')
# Out:
# test
# CPU times: user 48 µs, sys: 31 µs, total: 79 µs
# Wall time: 64.1 µs

# %% [markdown]
# ## Loading

# %%
# %%time 
pddf = pd.read_csv('data/sales.csv')
# Out:
# CPU times: user 5.94 s, sys: 531 ms, total: 6.47 s
# Wall time: 6.46 s

# %%
# %%time 
psdf = ps.read_csv('data/sales.csv')
# Out:
# CPU times: user 18.4 ms, sys: 3 ms, total: 21.4 ms
# Wall time: 5.16 s

# %% [markdown]
# ## Transformations

# %%
pddf
# Out:
#                                Region           Country        Item Type  \
# 0               Australia and Oceania             Palau  Office Supplies
# 1                              Europe            Poland        Beverages
# 2                       North America            Canada           Cereal
# 3                              Europe           Belarus           Snacks
# 4        Middle East and North Africa              Oman           Cereal
# ...                               ...               ...              ...
# 4999995  Middle East and North Africa              Iraq        Household
# 4999996                        Europe            Monaco             Meat
# 4999997         Australia and Oceania   Solomon Islands          Clothes
# 4999998         Australia and Oceania  Marshall Islands        Cosmetics
# 4999999                        Europe            Greece  Office Supplies
#
#         Sales Channel Order Priority Order Date   Order ID   Ship Date  \
# ...

# %%
# %%time
pddf['div'] = pddf['Total Revenue']/pddf['Total Cost']
# Out:
# CPU times: user 152 ms, sys: 92.4 ms, total: 245 ms
# Wall time: 72.8 ms

# %%
# %%time
psdf['div'] = psdf['Total Revenue']/psdf['Total Cost']
# Out:
# CPU times: user 18.7 ms, sys: 11 ms, total: 29.7 ms
# Wall time: 83 ms

# %% [markdown]
# # Size

# %%
import sys

# %%
def size(obj):
    return print(f'''{round(sys.getsizeof(pddf)/1E6,2)} M''')

# %%
size(pddf)
# Out:
# 2608.56 M

# %%
size(psdf)
# Out:
# 2608.56 M

# %%
type(pddf)
# Out:
# pandas.core.frame.DataFrame

# %%
type(psdf)
# Out:
# pyspark.pandas.frame.DataFrame
